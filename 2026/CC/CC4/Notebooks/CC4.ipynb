# %% [markdown]
# # CC4

# %%
import numpy as np
import scipy as sp
import matplotlib as plt

# %% [markdown]
# ## ACP

# %%
eignenvalues = np.array([3/2, 1/2]) * np.eye(2)
eigenvectors = np.array([[1., 1.], [1., -1]]) * 1 / np.sqrt(2)
eignenvalues, eigenvectors
# Out:
# (array([[1.5, 0. ],
#         [0. , 0.5]]),
#  array([[ 0.70710678,  0.70710678],
#         [ 0.70710678, -0.70710678]]))

# %%
cov = eigenvectors @ eignenvalues @ eigenvectors.T
cov
# Out:
# array([[1. , 0.5],
#        [0.5, 1. ]])

# %%
1.5/2.0
# Out:
# 0.75

# %%
mu = np.array([0., 0., 0.])
cov = np.array([[1., 0., -0.1], [0., 1., 0.5], [-0.1, 0.5, 1.]])
cov
# Out:
# array([[ 1. ,  0. , -0.1],
#        [ 0. ,  1. ,  0.5],
#        [-0.1,  0.5,  1. ]])

# %%
eigenvalues, eigenvectors = np.linalg.eig(cov)

# %%
eigenvalues
i = np.argsort(eigenvalues)
eigenvalues[i]
# Out:
# array([0.49009805, 1.        , 1.50990195])

# %%
1 - np.sqrt(26/100), 1 + np.sqrt(26/100)
# Out:
# (np.float64(0.4900980486407215), np.float64(1.5099019513592786))

# %%
eigenvectors[:, i]
# Out:
# array([[-7.07106781e-01, -1.08866324e-16,  7.07106781e-01],
#        [ 6.93375245e-01,  1.96116135e-01,  6.93375245e-01],
#        [-1.38675049e-01,  9.80580676e-01, -1.38675049e-01]])

# %%
U = np.array([[-0.5, 0., 0.5], [], []])
